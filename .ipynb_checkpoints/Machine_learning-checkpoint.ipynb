# %%
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df = pd.read_pickle("hamzah.pkl")

# %%
df.head(-100)
DF = df[0:1000]
# Out:
#          ID       Date                   Block                Primary Type  \
# 0  11778851 2016-01-01       043XX S MOZART ST  OFFENSE INVOLVING CHILDREN
# 1  11768978 2016-01-01  088XX S MARSHFIELD AVE                 SEX OFFENSE
# 2  11845914 2016-01-01      027XX S WHIPPLE ST               OTHER OFFENSE
# 3  11845531 2016-01-01         005XX E 89TH PL  OFFENSE INVOLVING CHILDREN
# 4  11842829 2016-01-01     078XX S LOOMIS BLVD          DECEPTIVE PRACTICE
#
#                            Description Location Description  Arrest  Domestic  \
# 0         CRIM SEX ABUSE BY FAM MEMBER            RESIDENCE       0         1
# 1            AGG CRIMINAL SEXUAL ABUSE            APARTMENT       0         0
# 2       HARASSMENT BY ELECTRONIC MEANS            RESIDENCE       0         1
# 3        SEX ASSLT OF CHILD BY FAM MBR            APARTMENT       0         1
# 4  FINANCIAL IDENTITY THEFT OVER $ 300                OTHER       0         0
#
#    Beat  District  Ward  Community Area  Day  Month  Year
# 0   922         9    15              58    1      1  2016
# 1  2221        22    21              71    1      1  2016
# 2  1033        10    12              30    1      1  2016
# 3   633         6     9              44    1      1  2016
# 4   612         6    17              71    1      1  2016

# %%
Y_df = df[['Description']]
X_df = df[['Day','Month','Community Area']]
display(Y_df.head())
display(X_df.head())
# Out:
#                            Description
# 0         CRIM SEX ABUSE BY FAM MEMBER
# 1            AGG CRIMINAL SEXUAL ABUSE
# 2       HARASSMENT BY ELECTRONIC MEANS
# 3        SEX ASSLT OF CHILD BY FAM MBR
# 4  FINANCIAL IDENTITY THEFT OVER $ 300
#    Day  Month  Community Area
# 0    1      1              58
# 1    1      1              71
# 2    1      1              30
# 3    1      1              44
# 4    1      1              71

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_std = scaler.fit_transform(X_df)

# %%
clf = LogisticRegression(random_state=0, multi_class='multinomial', solver='newton-cg')

# %%
model = clf.fit(X_std, Y_df)
# Out:
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bf72ae154484> in <module>
# ----> 1 model = clf.fit(X_std, Y_df)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1604                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1605                       sample_weight=sample_weight)
# -> 1606             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1607
#    1608         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1001             # remaining jobs.
#    1002             self._iterating = False
# -> 1003             if self.dispatch_one_batch(iterator):
#    1004                 self._iterating = self._original_iterator is not None
#    1005
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     832                 return False
#     833             else:
# --> 834                 self._dispatch(tasks)
#     835                 return True
#     836
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     751         with self._lock:
#     752             job_idx = len(self._jobs)
# --> 753             job = self._backend.apply_async(batch, callback=cb)
#     754             # A job can complete so quickly than its callback is
#     755             # called before we get here, causing self._jobs to
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     199     def apply_async(self, func, callback=None):
#     200         """Schedule a func to be run"""
# --> 201         result = ImmediateResult(func)
#     202         if callback:
#     203             callback(result)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     580         # Don't delay the application, to avoid keeping the input
#     581         # arguments in memory
# --> 582         self.results = batch()
#     583
#     584     def get(self):
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     952             args = (X, target, 1. / C, sample_weight)
#     953             w0, n_iter_i = newton_cg(hess, func, grad, w0, args=args,
# --> 954                                      maxiter=max_iter, tol=tol)
#     955         elif solver == 'liblinear':
#     956             coef_, intercept_, n_iter_i, = _fit_liblinear(
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\optimize.py in newton_cg(grad_hess, func, grad, x0, args, tol, maxiter, maxinner, line_search, warn)
#     171         # Compute a search direction pk by applying the CG method to
#     172         #  del2 f(xk) p = - fgrad f(xk) starting from 0.
# --> 173         fgrad, fhess_p = grad_hess(xk, *args)
#     174
#     175         absgrad = np.abs(fgrad)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py in _multinomial_grad_hess(w, X, Y, alpha, sample_weight)
#     396     # `loss` is unused. Refactoring to avoid computing it does not
#     397     # significantly speed up the computation and decreases readability
# --> 398     loss, grad, p = _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     399     sample_weight = sample_weight[:, np.newaxis]
#     400
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     342     grad = np.zeros((n_classes, n_features + bool(fit_intercept)),
#     343                     dtype=X.dtype)
# --> 344     loss, p, w = _multinomial_loss(w, X, Y, alpha, sample_weight)
#     345     sample_weight = sample_weight[:, np.newaxis]
#     346     diff = sample_weight * (p - Y)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py in _multinomial_loss(w, X, Y, alpha, sample_weight)
#     292     p = safe_sparse_dot(X, w.T)
#     293     p += intercept
# --> 294     p -= logsumexp(p, axis=1)[:, np.newaxis]
#     295     loss = -(sample_weight * Y * p).sum()
#     296     loss += 0.5 * alpha * squared_norm(w)
#
# c:\users\hamzah baig\appdata\local\programs\python\python37\lib\site-packages\scipy\special\_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#     113
#     114     # suppress warnings about log of zero
# --> 115     with np.errstate(divide='ignore'):
#     116         s = np.sum(tmp, axis=axis, keepdims=keepdims)
#     117         if return_sign:
#
# KeyboardInterrupt:
